# %%
import ray

# %%
import darwin

# %%
darwin.init()

# %%
df = darwin.get_registered_feature_group('contest_persona_predictions').get_offline_features().to_ray_df()

# %%
df.show(1)
# Out:
# {'userid': 118051208, 'prds': '[-1, 17217, 16885, 14612, 13531, 10501, 10306, 14, 17718, 17717, 17464, 17463, 17114, 17113, 17094, 17093, 16577, 14950, 14152, 14129, 13918, 17967, 17966, 17553, 17552, 17517, 17516, 17485, 17484, 17192, 17191, 17145, 17144, 14039, 13986, 13532, 13533, 17281, 17278, 15288, 15284, 15251, 15247, 14708, 14683, 14663, 14643, 14631, 12131, 12127, 12120, 12111, 12090, 12082, 12081, 12071, 12054, 12045, 12036, 11156, 11147, 11136, 11128, 11115, 11109, 11096, 11084, 11075, 11070, 11064, 11045, 9586, 9584, 25, 12153, 11387, 15319, 15149, 13591, 11238, 10201, 23, 12974, 19728, 19727, 19724, 19719, 19718, 19715, 19714, 19713, 19711, 19690, 19689, 19685, 19684, 19683, 19673, 19672, 19671, 19670, 19669, 19668, 19665, 19664, 19663, 19661, 19658, 19657, 19656, 19654, 19653, 19644, 19643, 19640, 19639, 19637, 19636, 19631, 19630, 19628, 19627, 19618, 19617, 19611, 19610, 19585, 19580, 19579, 19575, 19574, 19568, 19567, 19519, 19518, 19516, 19515, 19513, 19512, 19511, 
# ...

# %%
# Out:
# /bin/bash: make: command not found
